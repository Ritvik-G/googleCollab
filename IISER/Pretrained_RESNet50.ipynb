# %% [markdown]
# ## **Importing Dependencies**

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import os
import torch
import torchvision
import tarfile
from zipfile import ZipFile
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision
from torchvision.models import ResNet50_Weights
torchvision.__version__
# Out:
# '0.13.0+cu113'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
with ZipFile('/content/drive/MyDrive/dataset.zip', 'r') as zip:
    zip.extractall(path='./data')

# %%
dir_path='./data/dataset/'
folders= os.listdir(dir_path)
print(folders)
for i in folders:
  print(os.listdir(dir_path+'/'+i))
# Out:
# ['training_data', 'validation_data', 'testing_data']
# ['smoking', 'notsmoking']
# ['smoking', 'notsmoking']
# ['abc149.jpg', 'abc378.jpg', 'abc252.jpg', 'abc263.jpg', 'abc205.jpg', 'abc363.jpg', 'abc187.jpg', 'abc233.jpg', 'abc285.jpg', 'abc230.jpg', 'abc310.jpg', 'abc139.jpg', 'abc218.jpg', 'abc145.jpg', 'abc277.jpg', 'abc153.jpg', 'abc026.jpg', 'abc161.jpg', 'abc105.jpg', 'abc075.jpg', 'abc015.jpg', 'abc123.jpg', 'abc053.jpg', 'abc041.jpg', 'abc337.jpg', 'abc240.jpg', 'abc196.jpg', 'abc120.jpg', 'abc338.jpg', 'abc108.jpg', 'abc054.jpg', 'abc116.jpg', 'abc397.jpg', 'abc276.jpg', 'abc072.jpg', 'abc119.jpg', 'abc296.jpg', 'abc360.jpg', 'abc198.jpg', 'abc173.jpg', 'abc109.jpg', 'abc326.jpg', 'abc101.jpg', 'abc086.jpg', 'abc380.jpg', 'abc246.jpg', 'abc334.jpg', 'abc374.jpg', 'abc095.jpg', 'abc129.jpg', 'abc284.jpg', 'abc220.jpg', 'abc057.jpg', 'abc189.jpg', 'abc302.jpg', 'abc228.jpg', 'abc163.jpg', 'abc184.jpg', 'abc100.jpg', 'abc180.jpg', 'abc011.jpg', 'abc330.jpg', 'abc350.jpg', 'abc185.jpg', 'abc358.jpg', 'abc391.jpg', 'abc144.jpg', 'abc039.jpg', 'abc044.jpg', 'abc176.jpg', 'abc322.jpg', 'abc274.jpg', 'abc286.jpg', 'abc186.jpg', 'abc297.jpg', 'abc102.jpg', 'abc081.jpg', 'abc206.jpg', 'abc010.jpg', 'abc150.jpg', 'abc047.jpg', 'abc245.jpg', 'abc320.jpg', 'abc242.jpg', 'abc328.jpg', 'abc289.jpg', 'abc348.jpg', 'abc043.jpg', 'abc182.jpg', 'abc260.jpg', 'abc194.jpg', 'abc007.jpg', 'abc381.jpg', 'abc070.jpg', 'abc155.jpg', 'abc122.jpg', 'abc027.jpg', 'abc321.jpg', 'abc305.jpg', 'abc353.jpg', 'abc017.jpg', 'abc375.jpg', 'abc359.jpg', 'abc158.jpg', 'abc069.jpg', 'abc249.jpg', 'abc193.jpg', 'abc154.jpg', 'abc136.jpg', 'abc089.jpg', 'abc034.jpg', 'abc091.jpg', 'abc231.jpg', 'abc393.jpg', 'abc112.jpg', 'abc093.jpg', 'abc272.jpg', 'abc165.jpg', 'abc055.jpg', 'abc241.jpg', 'abc292.jpg', 'abc037.jpg', 'abc183.jpg', 'abc389.jpg', 'abc388.jpg', 'abc146.jpg', 'abc084.jpg', 'abc283.jpg', 'abc266.jpg', 'abc022.jpg', 'abc172.jpg', 'abc295.jpg', 'abc315.jpg', 'abc303.jpg', 'abc083.jpg', 'abc018.jpg', 'abc060.jpg', 'abc138.jpg', 'abc049.jpg', 'abc023.jpg', 'abc125.jpg', 'abc255.jpg', 'abc362.jpg', 'abc351.jpg', 'abc065.jpg', 'abc395.jpg', 'abc128.jpg', 'abc333.jpg', 'abc341.jpg', 'abc207.jpg', 'abc332.jpg', 'abc229.jpg', 'abc352.jpg', 'abc006.jpg', 'abc056.jpg', 'abc216.jpg', 'abc074.jpg', 'abc299.jpg', 'abc099.jpg', 'abc004.jpg', 'abc171.jpg', 'abc308.jpg', 'abc126.jpg', 'abc024.jpg', 'abc130.jpg', 'abc304.jpg', 'abc217.jpg', 'abc349.jpg', 'abc371.jpg', 'abc036.jpg', 'abc331.jpg', 'abc127.jpg', 'abc250.JPG', 'abc279.jpg', 'abc336.jpg', 'abc085.jpg', 'abc076.jpg', 'abc247.jpg', 'abc104.jpg', 'abc223.jpg', 'abc327.jpg', 'abc199.jpg', 'abc312.jpg', 'abc275.jpg', 'abc038.jpg', 'abc235.jpg', 'abc135.jpg', 'abc382.JPG', 'abc028.jpg', 'abc188.jpg', 'abc212.jpg', 'abc269.jpeg', 'abc259.jpg', 'abc090.jpg', 'abc369.jpg', 'abc211.jpg', 'abc244.jpg', 'abc301.jpg', 'abc227.jpg', 'abc124.jpg', 'abc379.jpg', 'abc386.jpg', 'abc390.jpg', 'abc251.jpg', 'abc106.jpg', 'abc068.jpg', 'abc222.jpg', 'abc243.jpg', 'abc134.jpg', 'abc033.jpg', 'abc361.jpg', 'abc281.jpg', 'abc061.jpg', 'abc335.jpg', 'abc278.jpg', 'abc157.jpg', 'abc066.jpg', 'abc238.jpg', 'abc261.jpg', 'abc248.jpg', 'abc209.jpg', 'abc073.jpg', 'abc040.jpg', 'abc225.jpg', 'abc021.jpg', 'abc270.jpg', 'abc387.jpg', 'abc170.jpg', 'abc168.jpg', 'abc282.jpg', 'abc005.jpg', 'abc399.jpg', 'abc329.jpg', 'abc392.jpg', 'abc345.jpg', 'abc204.jpg', 'abc001.jpg', 'abc221.jpg', 'abc214.jpg', 'abc376.jpg', 'abc383.jpg', 'abc117.jpg', 'abc300.jpg', 'abc019.jpg', 'abc114.jpg', 'abc096.jpg', 'abc324.jpg', 'abc148.jpg', 'abc042.jpg', 'abc014.jpg', 'abc203.jpg', 'abc377.jpg', 'abc347.jpg', 'abc013.jpg', 'abc080.jpg', 'abc174.jpg', 'abc256.jpg', 'abc140.jpg', 'abc339.jpg', 'abc385.jpg', 'abc290.jpg', 'abc115.jpg', 'abc142.jpg', 'abc178.jpg', 'abc110.jpg', 'abc396.jpg', 'abc307.jpg', 'abc306.jpg', 'abc357.jpg', 'abc016.jpg', 'abc094.jpg', 'abc314.jpg', 'abc029.jpg', 'abc088.jpg', 'abc046.jpg', 'abc167.jpg', 'abc317.JPG', 'abc067.jpg', 'abc215.jpg', 'abc064.jpg', 'abc030.jpg', 'abc313.jpg', 'abc177.jpg', 'abc118.jpg', 'abc236.jpg', 'abc219. ...

# %%
input_path = "./data/dataset/"

# %% [markdown]
# ## **Creating PyTorch generators**

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'training_data':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation_data':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
}

image_datasets = {
    'training_data': 
    datasets.ImageFolder(input_path + 'training_data', data_transforms['training_data']),
    'validation_data': 
    datasets.ImageFolder(input_path + 'validation_data/', data_transforms['validation_data'])
}

dataloaders = {
    'training_data':
    torch.utils.data.DataLoader(image_datasets['training_data'],
                                batch_size=32,
                                shuffle=True), 
    'validation_data':
    torch.utils.data.DataLoader(image_datasets['validation_data'],
                                batch_size=32,
                                shuffle=False,) 
}

# %% [markdown]
# ## **Creating the network**

# %%
model = models.resnet50(weights=ResNet50_Weights.DEFAULT).to(device)
    
for param in model.parameters():
    param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters())

# %% [markdown]
# ## **Training the model**

# %%
def train_model(model, criterion, optimizer, num_epochs):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['training_data', 'validation_data']:
            if phase == 'training_data':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'training_data':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# training_data loss: 0.4057, acc: 0.8124
# validation_data loss: 0.2562, acc: 0.8900
# Epoch 2/100
# ----------
# training_data loss: 0.2491, acc: 0.9012
# validation_data loss: 0.2208, acc: 0.9175
# Epoch 3/100
# ----------
# training_data loss: 0.2297, acc: 0.9081
# validation_data loss: 0.2374, acc: 0.8900
# Epoch 4/100
# ----------
# training_data loss: 0.2137, acc: 0.9205
# validation_data loss: 0.2223, acc: 0.9175
# Epoch 5/100
# ----------
# training_data loss: 0.1904, acc: 0.9236
# validation_data loss: 0.2818, acc: 0.8875
# Epoch 6/100
# ----------
# training_data loss: 0.1613, acc: 0.9348
# validation_data loss: 0.3283, acc: 0.8650
# Epoch 7/100
# ----------
# training_data loss: 0.1663, acc: 0.9298
# validation_data loss: 0.2257, acc: 0.9075
# Epoch 8/100
# ----------
# training_data loss: 0.1481, acc: 0.9435
# validation_data loss: 0.2129, acc: 0.9100
# Epoch 9/100
# ----------
# training_data loss: 0.1300, acc: 0.9497
# validation_data loss: 0.4640, acc: 0.8475
# Epoch 10/100
# ----------
# training_data loss: 0.1514, acc: 0.9385
# validation_data loss: 0.2121, acc: 0.9175
# Epoch 11/100
# ----------
# training_data loss: 0.1212, acc: 0.9559
# validation_data loss: 0.1960, acc: 0.9325
# Epoch 12/100
# ----------
# training_data loss: 0.1115, acc: 0.9584
# validation_data loss: 0.2202, acc: 0.9050
# Epoch 13/100
# ----------
# training_data loss: 0.1142, acc: 0.9534
# validation_data loss: 0.2418, acc: 0.9100
# Epoch 14/100
# ----------
# training_data loss: 0.1153, acc: 0.9553
# validation_data loss: 0.1897, acc: 0.9200
# Epoch 15/100
# ----------
# training_data loss: 0.1000, acc: 0.9634
# validation_data loss: 0.3177, acc: 0.8875
# Epoch 16/100
# ----------
# training_data loss: 0.0942, acc: 0.9640
# validation_data loss: 0.2064, acc: 0.9225
# Epoch 17/100
# ----------
# training_data loss: 0.0781, acc: 0.9720
# validation_data loss: 0.2642, acc: 0.9075
# Epoch 18/100
# ----------
# training_data loss: 0.1108, acc: 0.9609
# validation_data loss: 0.2214, acc: 0.9050
# Epoch 19/100
# ----------
# training_data loss: 0.0879, acc: 0.9615
# validation_data loss: 0.2786, acc: 0.8975
# Epoch 20/100
# ----------
# training_data loss: 0.1039, acc: 0.9590
# validation_data loss: 0.2245, acc: 0.9200
# Epoch 21/100
# ----------
# training_data loss: 0.0616, acc: 0.9783
# validation_data loss: 0.2147, acc: 0.9250
# Epoch 22/100
# ----------
# training_data loss: 0.0788, acc: 0.9708
# validation_data loss: 0.2580, acc: 0.9175
# Epoch 23/100
# ----------
# training_data loss: 0.0705, acc: 0.9776
# validation_data loss: 0.2528, acc: 0.9150
# Epoch 24/100
# ----------
# training_data loss: 0.0603, acc: 0.9789
# validation_data loss: 0.2219, acc: 0.9225
# Epoch 25/100
# ----------
# training_data loss: 0.0705, acc: 0.9752
# validation_data loss: 0.2323, acc: 0.9225
# Epoch 26/100
# ----------
# training_data loss: 0.0578, acc: 0.9814
# validation_data loss: 0.2895, acc: 0.8975
# Epoch 27/100
# ----------
# training_data loss: 0.0599, acc: 0.9789
# validation_data loss: 0.3338, acc: 0.8950
# Epoch 28/100
# ----------
# training_data loss: 0.0508, acc: 0.9801
# validation_data loss: 0.2578, acc: 0.9125
# Epoch 29/100
# ----------
# training_data loss: 0.0369, acc: 0.9882
# validation_data loss: 0.2558, acc: 0.9250
# Epoch 30/100
# ----------
# training_data loss: 0.0452, acc: 0.9832
# validation_data loss: 0.2880, acc: 0.9225
# Epoch 31/100
# ----------
# training_data loss: 0.0468, acc: 0.9820
# validation_data loss: 0.2350, acc: 0.9250
# Epoch 32/100
# ----------
# training_data loss: 0.0533, acc: 0.9801
# validation_data loss: 0.2172, acc: 0.9350
# Epoch 33/100
# ----------
# training_data loss: 0.0338, acc: 0.9901
# validation_data loss: 0.2447, acc: 0.9275
# Epoch 34/100
# ----------
# training_data loss: 0.0481, acc: 0.9826
# validation_data loss: 0.3058, acc: 0.9025
# Epoch 35/100
# ----------
# training_data loss: 0.0425, acc: 0.9857
# validation_data loss: 0.2300, acc: 0.9325
# Epoch 36/100
# ----------
# training_data loss: 0.0481, acc: 0.9851
# validation_data loss: 0.2585, acc: 0.9225
# Epoch 37/100
# ----------
# training_data loss: 0.0553, acc: 0.9801
# validation_data loss: 0.2825, acc: 0.9025
# Epoch 38/100
# ----------
# training_data loss: 0.0334, acc: 0.9925
# validation_data loss: 0.2127, acc: 0.9300
# Epoch 39/100
# ----------
# training_data loss: 0.0338, acc: 0.9907
# validation_data loss: 0.2365, acc: 0.9275
# Epoch 40/100
# ----------
# training_data loss: 0.0302, acc: 0.9913
# validation_data loss: 0.2691, acc: 0.9325
# Epoch 41/100
# ----------
# training_data loss: 0.0402, acc: 0.9857
# validation_data loss: 0.2475, acc: 0.9200
# Epoch 42/100
# ----------
# training_data loss: 0.0249, acc: 0.9919
# validation_data loss: 0.2695, acc: 0.9200
# Epoch 43/100
# ----------
# training_data loss: 0.0254, acc: 0.9913
# validation_data loss: 0.2858, acc: 0.9175
# Epoch 44/100
# ----------
# training_data loss: 0.0211, acc: 0.9932
# validation_data loss: 0.3032, acc: 0.9175
# Epoch 45/100
# ----------
# training_data loss: 0.0384, acc: 0.9857
# validation_data loss: 0.2646, acc: 0.9225
# Epoch 46/100
# ----------
# training_data loss: 0.0264, acc: 0.9932
# validation_data loss: 0.2477, acc: 0.9300
# Epoch 47/100
# ----------
# training_data loss: 0.0209, acc: 0.9944
# validation_data loss: 0.2994, acc: 0.9050
# Epoch 48/100
# ----------
# training_data loss: 0.0353, acc: 0.9876
# validation_data loss: 0.2434, acc: 0.9400
# Epoch 49/100
# ----------
# training_data loss: 0.0185, acc: 0.9957
# validation_data loss: 0.2810, acc: 0.9350
# Epoch 50/100
# ----------
# training_data loss: 0.0261, acc: 0.9913
# validation_data loss: 0.3012, acc: 0.9200
# Epoch 51/100
# ----------
# training_data loss: 0.0296, acc: 0.9907
# validation_data loss: 0.2906, acc: 0.9175
# Epoch 52/100
# ----------
# training_data loss: 0.0221, acc: 0.9932
# validation_data loss: 0.2335, acc: 0.9350
# Epoch 53/100
# ----------
# training_data loss: 0.0205, acc: 0.9913
# validation_data loss: 0.3132, acc: 0.9050
# Epoch 54/100
# ----------
# training_data loss: 0.0199, acc: 0.9901
# validation_data loss: 0.3200, acc: 0.9000
# Epoch 55/100
# ----------
# training_data loss: 0.0290, acc: 0.9882
# validation_data loss: 0.2737, acc: 0.9200
# Epoch 56/100
# ----------
# training_data loss: 0.0298, acc: 0.9901
# validation_data loss: 0.3062, acc: 0.9150
# Epoch 57/100
# ----------
# training_data loss: 0.0201, acc: 0.9932
# validation_data loss: 0.2971, acc: 0.9075
# Epoch 58/100
# ----------
# training_data loss: 0.0183, acc: 0.9938
# validation_data loss: 0.3081, acc: 0.9200
# Epoch 59/100
# ----------
# training_data loss: 0.0256, acc: 0.9919
# validation_data loss: 0.3652, acc: 0.9125
# Epoch 60/100
# ----------
# training_data loss: 0.0159, acc: 0.9957
# validation_data loss: 0.3424, acc: 0.9225
# Epoch 61/100
# ----------
# training_data loss: 0.0232, acc: 0.9938
# validation_data loss: 0.3378, acc: 0.9075
# Epoch 62/100
# ----------
# training_data loss: 0.0240, acc: 0.9913
# validation_data loss: 0.3240, acc: 0.9100
# Epoch 63/100
# ----------
# training_data loss: 0.0204, acc: 0.9919
# validation_data loss: 0.2731, acc: 0.9350
# Epoch 64/100
# ----------
# training_data loss: 0.0173, acc: 0.9944
# validation_data loss: 0.3265, acc: 0.9175
# Epoch 65/100
# ----------
# training_data loss: 0.0178, acc: 0.9932
# validation_data loss: 0.2986, acc: 0.9275
# Epoch 66/100
# ----------
# training_data loss: 0.0203, acc: 0.9938
# validation_data loss: 0.3170, acc: 0.9250
# Epoch 67/100
# ----------
# training_data loss: 0.0179, acc: 0.9944
# validation_data loss: 0.3809, acc: 0.9150
# Epoch 68/100
# ----------
# training_data loss: 0.0208, acc: 0.9913
# validation_data loss: 0.3968, acc: 0.9000
# Epoch 69/100
# ----------
# training_data loss: 0.0245, acc: 0.9925
# validation_data loss: 0.2588, acc: 0.9350
# Epoch 70/100
# ----------
# training_data loss: 0.0174, acc: 0.9938
# validation_data loss: 0.3331, acc: 0.9325
# Epoch 71/100
# ----------
# training_data loss: 0.0127, acc: 0.9950
# validation_data loss: 0.3639, acc: 0.9250
# Epoch 72/100
# ----------
# training_data loss: 0.0160, acc: 0.9957
# validation_data loss: 0.3737, acc: 0.9250
# Epoch 73/100
# ----------
# training_data loss: 0.0221, acc: 0.9919
# validation_data loss: 0.3131, acc: 0.9200
# Epoch 74/100
# ----------
# training_data loss: 0.0181, acc: 0.9938
# validation_data loss: 0.3216, acc: 0.9175
# Epoch 75/100
# ----------
# training_data loss: 0.0169, acc: 0.9938
# validation_data loss: 0.3576, acc: 0.9125
# Epoch 76/100
# ----------
# training_data loss: 0.0170, acc: 0.9938
# validation_data loss: 0.2983, acc: 0.9200
# Epoch 77/100
# ----------
# training_data loss: 0.0140, acc: 0.9963
# validation_data loss: 0.4083, acc: 0.9125
# Epoch 78/100
# ----------
# training_data loss: 0.0145, acc: 0.9944
# validation_data loss: 0.3573, acc: 0.9150
# Epoch 79/100
# ----------
# training_data loss: 0.0229, acc: 0.9932
# validation_data loss: 0.3633, acc: 0.9050
# Epoch 80/100
# ----------
# training_data loss: 0.0146, acc: 0.9950
# validation_data loss: 0.3813, acc: 0.9075
# Epoch 81/100
# ----------
# training_data loss: 0.0326, acc: 0.9919
# validation_data loss: 0.3369, acc: 0.9125
# Epoch 82/100
# ----------
# training_data loss: 0.0176, acc: 0.9950
# validation_data loss: 0.3199, acc: 0.9175
# Epoch 83/100
# ----------
# training_data loss: 0.0183, acc: 0.9925
# validation_data loss: 0.3897, acc: 0.9050
# Epoch 84/100
# ----------
# training_data loss: 0.0089, acc: 0.9975
# validation_data loss: 0.3174, acc: 0.9175
# Epoch 85/100
# ----------
# training_data loss: 0.0197, acc: 0.9925
# validation_data loss: 0.3366, acc: 0.9300
# Epoch 86/100
# ----------
# training_data loss: 0.0162, acc: 0.9957
# validation_data loss: 0.4376, acc: 0.8975
# Epoch 87/100
# ----------
# training_data loss: 0.0128, acc: 0.9969
# validation_data loss: 0.3614, acc: 0.9125
# Epoch 88/100
# ----------
# training_data loss: 0.0114, acc: 0.9963
# validation_data loss: 0.3432, acc: 0.9250
# Epoch 89/100
# ----------
# training_data loss: 0.0103, acc: 0.9963
# validation_data loss: 0.4316, acc: 0.9075
# Epoch 90/100
# ----------
# training_data loss: 0.0092, acc: 0.9988
# validation_data loss: 0.3570, acc: 0.9200
# Epoch 91/100
# ----------
# training_data loss: 0.0153, acc: 0.9957
# validation_data loss: 0.3933, acc: 0.9075
# Epoch 92/100
# ----------
# training_data loss: 0.0172, acc: 0.9919
# validation_data loss: 0.4133, acc: 0.9125
# Epoch 93/100
# ----------
# training_data loss: 0.0096, acc: 0.9975
# validation_data loss: 0.3711, acc: 0.9200
# Epoch 94/100
# ----------
# training_data loss: 0.0104, acc: 0.9969
# validation_data loss: 0.3956, acc: 0.9200
# Epoch 95/100
# ----------
# training_data loss: 0.0082, acc: 0.9988
# validation_data loss: 0.4005, acc: 0.9175
# Epoch 96/100
# ----------
# training_data loss: 0.0075, acc: 0.9981
# validation_data loss: 0.3432, acc: 0.9225
# Epoch 97/100
# ----------
# training_data loss: 0.0086, acc: 0.9975
# validation_data loss: 0.3470, acc: 0.9250
# Epoch 98/100
# ----------
# training_data loss: 0.0078, acc: 0.9981
# validation_data loss: 0.4830, acc: 0.9025
# Epoch 99/100
# ----------
# training_data loss: 0.0077, acc: 0.9981
# validation_data loss: 0.3613, acc: 0.9275
# Epoch 100/100
# ----------
# training_data loss: 0.0055, acc: 0.9975
# validation_data loss: 0.4117, acc: 0.9150

# %% [markdown]
# ## **Save and load the model**

# %%
# !mkdir models
# !mkdir models/pytorch

# %%
torch.save(model_trained.state_dict(), 'models/pytorch/weights.h5')

# %%
model = models.resnet50(weights=ResNet50_Weights.DEFAULT).to(device)
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)
model.load_state_dict(torch.load('models/pytorch/weights.h5'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## **Making predictions**

# %%
validation_img_paths = ["validation_data/notsmoking/notsmoking_0112.jpg",
                        "validation_data/notsmoking/notsmoking_0179.jpg",
                        "validation_data/smoking/smoking_0085.jpg"]
img_list = [Image.open(input_path + img_path) for img_path in validation_img_paths]

# %%
validation_batch = torch.stack([data_transforms['validation_data'](img).to(device)
                                for img in img_list])

# %%
pred_logits_tensor = model(validation_batch)
pred_logits_tensor
# Out:
# tensor([[ 6.9774, -7.0765],
#         [ 2.4480, -2.2180],
#         [-3.3907,  3.9031]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
pred_probs = F.softmax(pred_logits_tensor, dim=1).cpu().data.numpy()
pred_probs
# Out:
# array([[9.9999917e-01, 7.8792237e-07],
#        [9.9067724e-01, 9.3227318e-03],
#        [6.7924708e-04, 9.9932075e-01]], dtype=float32)

# %%
fig, axs = plt.subplots(1, len(img_list), figsize=(20, 5))
for i, img in enumerate(img_list):
    ax = axs[i]
    ax.axis('off')
    ax.set_title("{:.0f}% notsmoking, {:.0f}% smoking".format(100*pred_probs[i,0],
                                                            100*pred_probs[i,1]))
    ax.imshow(img)
