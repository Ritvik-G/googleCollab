# %% [markdown]
# ## **Importing dependencies**

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import os
import torch
import torchvision
import tarfile
from zipfile import ZipFile
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision
from torchvision.models import ResNet50_Weights
torchvision.__version__
# Out:
# '0.13.0+cu113'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
with ZipFile('/content/drive/MyDrive/custom_dataset.zip', 'r') as zip:
    zip.extractall(path='./data')

# %%
dir_path='./data/dataset/'
folders= os.listdir(dir_path)
print(folders)
for i in folders:
  print(os.listdir(dir_path+'/'+i))
# Out:
# ['validation_data', 'training_data']
# ['notsmoking', 'smoking']
# ['notsmoking', 'smoking']

# %%
input_path = "./data/dataset/"

# %% [markdown]
# ## **Creating pyTorch generators**

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'training_data':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation_data':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
}

image_datasets = {
    'training_data': 
    datasets.ImageFolder(input_path + 'training_data/', data_transforms['training_data']),
    'validation_data': 
    datasets.ImageFolder(input_path + 'validation_data/', data_transforms['validation_data'])
}

dataloaders = {
    'training_data':
    torch.utils.data.DataLoader(image_datasets['training_data'],
                                batch_size=32,
                                shuffle=True), 
    'validation_data':
    torch.utils.data.DataLoader(image_datasets['validation_data'],
                                batch_size=32,
                                shuffle=False,) 
}

# %% [markdown]
# ## **Creating the network**

# %%
model = models.resnet50(weights=None).to(device)
    
for param in model.parameters():
    param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters())

# %% [markdown]
# ## **Training the model**

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['training_data', 'validation_data']:
            if phase == 'training_data':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'training_data':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# training_data loss: 1.0200, acc: 0.4875
# validation_data loss: 0.6944, acc: 0.5000
# Epoch 2/100
# ----------
# training_data loss: 0.7333, acc: 0.5125
# validation_data loss: 0.7167, acc: 0.5000
# Epoch 3/100
# ----------
# training_data loss: 0.6979, acc: 0.5438
# validation_data loss: 0.6940, acc: 0.5000
# Epoch 4/100
# ----------
# training_data loss: 0.7361, acc: 0.5000
# validation_data loss: 0.6929, acc: 0.5000
# Epoch 5/100
# ----------
# training_data loss: 0.6889, acc: 0.5500
# validation_data loss: 0.7141, acc: 0.5000
# Epoch 6/100
# ----------
# training_data loss: 0.6959, acc: 0.5375
# validation_data loss: 0.7165, acc: 0.5000
# Epoch 7/100
# ----------
# training_data loss: 0.6844, acc: 0.5563
# validation_data loss: 0.6959, acc: 0.5000
# Epoch 8/100
# ----------
# training_data loss: 0.7006, acc: 0.5062
# validation_data loss: 0.6905, acc: 0.5000
# Epoch 9/100
# ----------
# training_data loss: 0.7049, acc: 0.5125
# validation_data loss: 0.7185, acc: 0.5000
# Epoch 10/100
# ----------
# training_data loss: 0.6821, acc: 0.5687
# validation_data loss: 0.6880, acc: 0.5500
# Epoch 11/100
# ----------
# training_data loss: 0.6796, acc: 0.5500
# validation_data loss: 0.6774, acc: 0.7000
# Epoch 12/100
# ----------
# training_data loss: 0.6870, acc: 0.5875
# validation_data loss: 0.6870, acc: 0.5500
# Epoch 13/100
# ----------
# training_data loss: 0.6884, acc: 0.5438
# validation_data loss: 0.6866, acc: 0.5500
# Epoch 14/100
# ----------
# training_data loss: 0.6629, acc: 0.6125
# validation_data loss: 0.6714, acc: 0.6250
# Epoch 15/100
# ----------
# training_data loss: 0.6916, acc: 0.5000
# validation_data loss: 0.6727, acc: 0.5250
# Epoch 16/100
# ----------
# training_data loss: 0.6849, acc: 0.5188
# validation_data loss: 0.6858, acc: 0.5250
# Epoch 17/100
# ----------
# training_data loss: 0.6869, acc: 0.5125
# validation_data loss: 0.6732, acc: 0.5250
# Epoch 18/100
# ----------
# training_data loss: 0.6716, acc: 0.5625
# validation_data loss: 0.6722, acc: 0.5250
# Epoch 19/100
# ----------
# training_data loss: 0.6886, acc: 0.5312
# validation_data loss: 0.6744, acc: 0.5500
# Epoch 20/100
# ----------
# training_data loss: 0.6812, acc: 0.5625
# validation_data loss: 0.6849, acc: 0.5500
# Epoch 21/100
# ----------
# training_data loss: 0.6848, acc: 0.5625
# validation_data loss: 0.6740, acc: 0.5500
# Epoch 22/100
# ----------
# training_data loss: 0.6747, acc: 0.5813
# validation_data loss: 0.6697, acc: 0.6250
# Epoch 23/100
# ----------
# training_data loss: 0.6866, acc: 0.5438
# validation_data loss: 0.6815, acc: 0.5250
# Epoch 24/100
# ----------
# training_data loss: 0.6767, acc: 0.5438
# validation_data loss: 0.6776, acc: 0.5500
# Epoch 25/100
# ----------
# training_data loss: 0.6775, acc: 0.6063
# validation_data loss: 0.6670, acc: 0.6250
# Epoch 26/100
# ----------
# training_data loss: 0.7086, acc: 0.4938
# validation_data loss: 0.6790, acc: 0.5250
# Epoch 27/100
# ----------
# training_data loss: 0.6934, acc: 0.5250
# validation_data loss: 0.6826, acc: 0.5250
# Epoch 28/100
# ----------
# training_data loss: 0.6784, acc: 0.5375
# validation_data loss: 0.6717, acc: 0.6250
# Epoch 29/100
# ----------
# training_data loss: 0.6853, acc: 0.5375
# validation_data loss: 0.6765, acc: 0.6250
# Epoch 30/100
# ----------
# training_data loss: 0.6837, acc: 0.6063
# validation_data loss: 0.6812, acc: 0.5500
# Epoch 31/100
# ----------
# training_data loss: 0.6858, acc: 0.5500
# validation_data loss: 0.6827, acc: 0.5500
# Epoch 32/100
# ----------
# training_data loss: 0.6823, acc: 0.5312
# validation_data loss: 0.6783, acc: 0.5250
# Epoch 33/100
# ----------
# training_data loss: 0.6899, acc: 0.5750
# validation_data loss: 0.6816, acc: 0.5500
# Epoch 34/100
# ----------
# training_data loss: 0.6804, acc: 0.5438
# validation_data loss: 0.6774, acc: 0.5250
# Epoch 35/100
# ----------
# training_data loss: 0.6936, acc: 0.5125
# validation_data loss: 0.6838, acc: 0.5500
# Epoch 36/100
# ----------
# training_data loss: 0.6881, acc: 0.5250
# validation_data loss: 0.6906, acc: 0.5500
# Epoch 37/100
# ----------
# training_data loss: 0.6894, acc: 0.5062
# validation_data loss: 0.6765, acc: 0.5250
# Epoch 38/100
# ----------
# training_data loss: 0.6860, acc: 0.5312
# validation_data loss: 0.6743, acc: 0.6250
# Epoch 39/100
# ----------
# training_data loss: 0.6782, acc: 0.5687
# validation_data loss: 0.6799, acc: 0.5500
# Epoch 40/100
# ----------
# training_data loss: 0.6821, acc: 0.5500
# validation_data loss: 0.6842, acc: 0.5250
# Epoch 41/100
# ----------
# training_data loss: 0.6837, acc: 0.5438
# validation_data loss: 0.6812, acc: 0.5500
# Epoch 42/100
# ----------
# training_data loss: 0.6995, acc: 0.5062
# validation_data loss: 0.6729, acc: 0.6500
# Epoch 43/100
# ----------
# training_data loss: 0.6796, acc: 0.5875
# validation_data loss: 0.6781, acc: 0.5500
# Epoch 44/100
# ----------
# training_data loss: 0.6808, acc: 0.5750
# validation_data loss: 0.6820, acc: 0.5500
# Epoch 45/100
# ----------
# training_data loss: 0.6738, acc: 0.5813
# validation_data loss: 0.6751, acc: 0.5000
# Epoch 46/100
# ----------
# training_data loss: 0.6945, acc: 0.5375
# validation_data loss: 0.6784, acc: 0.5500
# Epoch 47/100
# ----------
# training_data loss: 0.6822, acc: 0.5500
# validation_data loss: 0.6780, acc: 0.5500
# Epoch 48/100
# ----------
# training_data loss: 0.6732, acc: 0.5625
# validation_data loss: 0.6712, acc: 0.6250
# Epoch 49/100
# ----------
# training_data loss: 0.6790, acc: 0.5250
# validation_data loss: 0.6774, acc: 0.5500
# Epoch 50/100
# ----------
# training_data loss: 0.6712, acc: 0.5687
# validation_data loss: 0.6801, acc: 0.5500
# Epoch 51/100
# ----------
# training_data loss: 0.6974, acc: 0.5062
# validation_data loss: 0.6813, acc: 0.5500
# Epoch 52/100
# ----------
# training_data loss: 0.6840, acc: 0.5250
# validation_data loss: 0.6698, acc: 0.6000
# Epoch 53/100
# ----------
# training_data loss: 0.6763, acc: 0.5875
# validation_data loss: 0.6715, acc: 0.5250
# Epoch 54/100
# ----------
# training_data loss: 0.6810, acc: 0.5438
# validation_data loss: 0.6771, acc: 0.5500
# Epoch 55/100
# ----------
# training_data loss: 0.6748, acc: 0.5687
# validation_data loss: 0.6820, acc: 0.5250
# Epoch 56/100
# ----------
# training_data loss: 0.6773, acc: 0.5750
# validation_data loss: 0.6748, acc: 0.5500
# Epoch 57/100
# ----------
# training_data loss: 0.6905, acc: 0.5500
# validation_data loss: 0.6686, acc: 0.6250
# Epoch 58/100
# ----------
# training_data loss: 0.6829, acc: 0.5312
# validation_data loss: 0.6756, acc: 0.5500
# Epoch 59/100
# ----------
# training_data loss: 0.6820, acc: 0.5438
# validation_data loss: 0.6795, acc: 0.5500
# Epoch 60/100
# ----------
# training_data loss: 0.6863, acc: 0.5250
# validation_data loss: 0.6750, acc: 0.5250
# Epoch 61/100
# ----------
# training_data loss: 0.6751, acc: 0.5875
# validation_data loss: 0.6748, acc: 0.5500
# Epoch 62/100
# ----------
# training_data loss: 0.6717, acc: 0.5875
# validation_data loss: 0.6741, acc: 0.5500
# Epoch 63/100
# ----------
# training_data loss: 0.6733, acc: 0.5687
# validation_data loss: 0.6721, acc: 0.5500
# Epoch 64/100
# ----------
# training_data loss: 0.6854, acc: 0.5250
# validation_data loss: 0.6690, acc: 0.5250
# Epoch 65/100
# ----------
# training_data loss: 0.6921, acc: 0.5500
# validation_data loss: 0.6852, acc: 0.5500
# Epoch 66/100
# ----------
# training_data loss: 0.6993, acc: 0.5750
# validation_data loss: 0.6656, acc: 0.6750
# Epoch 67/100
# ----------
# training_data loss: 0.6821, acc: 0.5750
# validation_data loss: 0.6957, acc: 0.5500
# Epoch 68/100
# ----------
# training_data loss: 0.6897, acc: 0.5625
# validation_data loss: 0.6694, acc: 0.5500
# Epoch 69/100
# ----------
# training_data loss: 0.6769, acc: 0.5500
# validation_data loss: 0.6687, acc: 0.6250
# Epoch 70/100
# ----------
# training_data loss: 0.6794, acc: 0.5625
# validation_data loss: 0.6744, acc: 0.5500
# Epoch 71/100
# ----------
# training_data loss: 0.6803, acc: 0.5750
# validation_data loss: 0.6791, acc: 0.5500
# Epoch 72/100
# ----------
# training_data loss: 0.6815, acc: 0.5125
# validation_data loss: 0.6743, acc: 0.5500
# Epoch 73/100
# ----------
# training_data loss: 0.6640, acc: 0.5750
# validation_data loss: 0.6765, acc: 0.5500
# Epoch 74/100
# ----------
# training_data loss: 0.6816, acc: 0.5563
# validation_data loss: 0.6751, acc: 0.5500
# Epoch 75/100
# ----------
# training_data loss: 0.6866, acc: 0.6063
# validation_data loss: 0.6682, acc: 0.5500
# Epoch 76/100
# ----------
# training_data loss: 0.6861, acc: 0.5500
# validation_data loss: 0.6776, acc: 0.5500
# Epoch 77/100
# ----------
# training_data loss: 0.6867, acc: 0.5438
# validation_data loss: 0.6820, acc: 0.5500
# Epoch 78/100
# ----------
# training_data loss: 0.6700, acc: 0.5687
# validation_data loss: 0.6740, acc: 0.5500
# Epoch 79/100
# ----------
# training_data loss: 0.6900, acc: 0.5500
# validation_data loss: 0.6709, acc: 0.6000
# Epoch 80/100
# ----------
# training_data loss: 0.6696, acc: 0.5875
# validation_data loss: 0.6740, acc: 0.5250
# Epoch 81/100
# ----------
# training_data loss: 0.6751, acc: 0.5125
# validation_data loss: 0.6756, acc: 0.5500
# Epoch 82/100
# ----------
# training_data loss: 0.6769, acc: 0.5687
# validation_data loss: 0.6707, acc: 0.5250
# Epoch 83/100
# ----------
# training_data loss: 0.6813, acc: 0.5687
# validation_data loss: 0.6724, acc: 0.5500
# Epoch 84/100
# ----------
# training_data loss: 0.6720, acc: 0.5125
# validation_data loss: 0.6795, acc: 0.5500
# Epoch 85/100
# ----------
# training_data loss: 0.6804, acc: 0.5563
# validation_data loss: 0.6726, acc: 0.5500
# Epoch 86/100
# ----------
# training_data loss: 0.6887, acc: 0.5438
# validation_data loss: 0.6719, acc: 0.5250
# Epoch 87/100
# ----------
# training_data loss: 0.6742, acc: 0.5687
# validation_data loss: 0.6720, acc: 0.5250
# Epoch 88/100
# ----------
# training_data loss: 0.6824, acc: 0.5375
# validation_data loss: 0.6731, acc: 0.5250
# Epoch 89/100
# ----------
# training_data loss: 0.6731, acc: 0.5875
# validation_data loss: 0.6708, acc: 0.5500
# Epoch 90/100
# ----------
# training_data loss: 0.6831, acc: 0.5312
# validation_data loss: 0.6753, acc: 0.5250
# Epoch 91/100
# ----------
# training_data loss: 0.6829, acc: 0.5750
# validation_data loss: 0.6714, acc: 0.5750
# Epoch 92/100
# ----------
# training_data loss: 0.6775, acc: 0.5563
# validation_data loss: 0.6705, acc: 0.5750
# Epoch 93/100
# ----------
# training_data loss: 0.6611, acc: 0.6250
# validation_data loss: 0.6676, acc: 0.5750
# Epoch 94/100
# ----------
# training_data loss: 0.6771, acc: 0.5375
# validation_data loss: 0.6705, acc: 0.5000
# Epoch 95/100
# ----------
# training_data loss: 0.6752, acc: 0.5750
# validation_data loss: 0.6688, acc: 0.5500
# Epoch 96/100
# ----------
# training_data loss: 0.6695, acc: 0.5875
# validation_data loss: 0.6679, acc: 0.5500
# Epoch 97/100
# ----------
# training_data loss: 0.6791, acc: 0.6000
# validation_data loss: 0.6753, acc: 0.5500
# Epoch 98/100
# ----------
# training_data loss: 0.6744, acc: 0.5687
# validation_data loss: 0.6660, acc: 0.6000
# Epoch 99/100
# ----------
# training_data loss: 0.6799, acc: 0.5438
# validation_data loss: 0.6696, acc: 0.5500
# Epoch 100/100
# ----------
# training_data loss: 0.6747, acc: 0.5687
# validation_data loss: 0.6675, acc: 0.5750

# %% [markdown]
# ## **Save and load the model**

# %%
# !mkdir models
# !mkdir models/pytorch

# %%
torch.save(model_trained.state_dict(), 'models/pytorch/weights.h5')

# %%
model = models.resnet50(weights=None).to(device)
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)
model.load_state_dict(torch.load('models/pytorch/weights.h5'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## **Making predictions**

# %%
validation_img_paths = ["validation_data/notsmoking/100.jpg",
                        "validation_data/smoking/23.jpg"]
img_list = [Image.open(input_path + img_path) for img_path in validation_img_paths]

# %%
validation_batch = torch.stack([data_transforms['validation_data'](img).to(device)
                                for img in img_list])

# %%
pred_logits_tensor = model(validation_batch)
pred_logits_tensor
# Out:
# tensor([[0.0040, 0.1336],
#         [0.2772, 0.0248]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
pred_probs = F.softmax(pred_logits_tensor, dim=1).cpu().data.numpy()
pred_probs
# Out:
# array([[0.46765837, 0.53234166],
#        [0.5627732 , 0.43722677]], dtype=float32)

# %%
fig, axs = plt.subplots(1, len(img_list), figsize=(20, 5))
for i, img in enumerate(img_list):
    ax = axs[i]
    ax.axis('off')
    ax.set_title("{:.0f}% smoking, {:.0f}% notsmoking".format(100*pred_probs[i,0],
                                                            100*pred_probs[i,1]))
    ax.imshow(img)
